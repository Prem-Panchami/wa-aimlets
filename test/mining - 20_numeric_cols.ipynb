# %%
import sys
sys.path.insert(0, '../')

import pandas as pd
import numpy as np

import aimlets.BasicUtils as basicutils
import aimlets.BasicPlots as basicplots

import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display, HTML


# %matplotlib inline

basicutils.set_defaults()

# %%
data = pd.read_csv('mining_temp_iot.csv')

basicutils.get_adv_desc_dfs(data);
# Out:
# <h4>SHAPE: 10000 ROWS x 21 COLUMNS</h4>
# <style  type="text/css" >
#     #T_f255d9f8_a082_11e8_95c9_acde48001122row0_col1 {
#             background-color:  #FFFF99;
#         }    #T_f255d9f8_a082_11e8_95c9_acde48001122row1_col1 {
#             background-color:  #FFFF99;
#         }    #T_f255d9f8_a082_11e8_95c9_acde48001122row2_col5 {
#             background-color:  #FFFF99;
#         }    #T_f255d9f8_a082_11e8_95c9_acde48001122row3_col5 {
#             background-color:  #FFFF99;
#         }    #T_f255d9f8_a082_11e8_95c9_acde48001122row4_col5 {
#             background-color:  #FFFF99;
#         }    #T_f255d9f8_a082_11e8_95c9_acde48001122row5_col5 {
#             background-color:  #FFFF99;
#         }    #T_f255d9f8_a082_11e8_95c9_acde48001122row6_col5 {
#             background-color:  #FFFF99;
#         }    #T_f255d9f8_a082_11e8_95c9_acde48001122row7_col1 {
#             background-color:  #FFFF99;
#         }    #T_f255d9f8_a082_11e8_95c9_acde48001122row8_col1 {
# ...

# %%
basicplots.plot_correlation(data, figsize=(15,12))
